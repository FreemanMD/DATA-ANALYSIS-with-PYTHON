# %% [markdown]
# # PANDAS

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np

# %%
serr = pd.Series([11,21,13,41,15,61])  #You can think of the pandas series as a column with labels in an excel sheet
serr
# Out:
# 0    11
# 1    21
# 2    13
# 3    41
# 4    15
# 5    61
# dtype: int64

# %%
a = pd.Series([1,2,3,4,5])
b = pd.Series(["a","b","c","d","e"])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
b
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
a = np.array([1,2,3,4,5])
b = np.array(["a","b","c","d","e"])

# %%
series = pd.Series(("Nik", "p", 30, "nick@email.com", 175))
series
# Out:
# 0               Nik
# 1                 p
# 2                30
# 3    nick@email.com
# 4               175
# dtype: object

# %%
dataframe1 = pd.DataFrame([("Nik", "p", 30, "nick@email.com", 175),
                          ("Evan", "d", 31, "evan@email.com", 170)],
                        columns = ["First Name", "Initial", "Age", "Email", "Weight"])

# %%
dataframe1
# Out:
#   First Name Initial  Age           Email  Weight
# 0        Nik       p   30  nick@email.com     175
# 1       Evan       d   31  evan@email.com     170

# %%
dataframe2 = pd.DataFrame({"First Name": ["Nick","Evan"],
                              "Initial": ["P","D"],
                              "Age":[30,31],
                              "Email":["email1","email2"],
                              "Height":[175,176]})

# %%
dataframe2
# Out:
#   First Name Initial  Age   Email  Height
# 0       Nick       P   30  email1     175
# 1       Evan       D   31  email2     176

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")

# %%
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head(10)
# Out:
#    Rank  Major_code                                      Major  \
# 0     1        2419                      PETROLEUM ENGINEERING
# 1     2        2416             MINING AND MINERAL ENGINEERING
# 2     3        2415                  METALLURGICAL ENGINEERING
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4     5        2418                        NUCLEAR ENGINEERING
# 5     6        2405                       CHEMICAL ENGINEERING
# 6     7        5001                 ASTRONOMY AND ASTROPHYSICS
# 7     8        2414                     MECHANICAL ENGINEERING
# 8     9        2401                      AEROSPACE ENGINEERING
# 9    10        2408                     ELECTRICAL ENGINEERING
#
#       Major_category  Total    Men  Women  ShareWomen  Median
# 0        Engineering   2339   2057    282    0.120564  110000
# 1        Engineering    756    679     77    0.101852   75000
# 2        Engineering    856    725    131    0.153037   73000
# ...

# %%
df.tail()
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
ser = pd.Series(list("Clarusway"))
ser
# Out:
# 0    C
# 1    l
# 2    a
# 3    r
# 4    u
# 5    s
# 6    w
# 7    a
# 8    y
# dtype: object

# %%
ser.sort_index(ascending=False)  #.sort_index : Sort Series by index labels
# Out:
# 8    y
# 7    a
# 6    w
# 5    s
# 4    u
# 3    r
# 2    a
# 1    l
# 0    C
# dtype: object

# %%
ser.isin(["w"])   #.isin : Return a boolean Series showing whether each element in the Series 
                    #matches an element in the passed sequence of values exactly
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
ser.keys()    #.keys : return the index labels of the given series object
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
ser.values    #   NO ()  --  .values : Return Series as ndarray or ndarray-like depending on the dtype
# Out:
# array(['C', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y'], dtype=object)

# %%
ser.items()   #creates and object

# %%
list(ser.items())   #you can list the object to see it
# Out:
# [(0, 'C'),
#  (1, 'l'),
#  (2, 'a'),
#  (3, 'r'),
#  (4, 'u'),
#  (5, 's'),
#  (6, 'w'),
#  (7, 'a'),
#  (8, 'y')]

# %%
print(*ser.items()) #alternatively you may print it with *
# Out:
# (0, 'C') (1, 'l') (2, 'a') (3, 'r') (4, 'u') (5, 's') (6, 'w') (7, 'a') (8, 'y')

# %%
df = pd.read_csv("the address or the link to my_file")  #.read_csv(): Read a comma-separated values (csv) file into DataFrame

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df1=pd.DataFrame(np.arange(1,24,2).reshape(3,4), columns=["var1","var2","var3","var4"])
df1
# Out:
#    var1  var2  var3  var4
# 0     1     3     5     7
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df1=pd.DataFrame(np.arange(1,24,2))   # create a dataframe from a list of numbers

# %%
df1=pd.DataFrame(np.arange(1,24,2).reshape(3,4))    #reshape it
df1
# Out:
#     0   1   2   3
# 0   1   3   5   7
# 1   9  11  13  15
# 2  17  19  21  23

# %%
df1=pd.DataFrame(np.arange(1,24,2).reshape(3,4), columns=["var1","var2","var3","var4"])  #assign column labels
df1

# %%
df1.tail(2)  #.tail(): This function returns last n rows from the object based on position, default n=5.
# Out:
#    var1  var2  var3  var4
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df.sample(n=5)   #.sample : Return a random sample of items from an axis of object
# Out:
#     Rank  Major_code                                   Major  \
# 24    25        2411  GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 53    54        3601                    BIOCHEMICAL SCIENCES
# 75    76        3609                                 ZOOLOGY
# 30    31        2100        COMPUTER AND INFORMATION SYSTEMS
# 72    73        6109           TREATMENT THERAPY PROFESSIONS
#
#              Major_category  Total    Men  Women  ShareWomen  Median
# 24              Engineering    720    488    232    0.322222   50000
# 53   Biology & Life Science  39107  18951  20156    0.515406   37400
# 75   Biology & Life Science   8409   3050   5359    0.637293   26000
# 30  Computers & Mathematics  36698  27392   9306    0.253583   45000
# 72                   Health  48491  13487  35004    0.721866   33000

# %%
df.shape
# Out:
# (76, 9)

# %%
df1.shape
# Out:
# (3, 4)

# %%
df.set_index("Major_code")
# Out:
#             Rank                                          Major  \
# Major_code
# 2419           1                          PETROLEUM ENGINEERING
# 2416           2                 MINING AND MINERAL ENGINEERING
# 2415           3                      METALLURGICAL ENGINEERING
# 2417           4      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418           5                            NUCLEAR ENGINEERING
# ...          ...                                            ...
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 2419                   Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.head()  #index has not changed in the original df
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df=df.set_index("Major_code")   #index has changed

# %%
df.head()
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")

# %%
df.set_index("Major_code", inplace=True)  # changed index in another way

# %%
df.head()
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
df.Major #selecting a column in the df
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df["Major"]  #another way of selecting a column in the df  --- works in cases where the first one doesnot work
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df.loc[2419]  #brings the case withe the index number
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.loc[2419, "Major"]  #brings the cell data for the specified index
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0]
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.iloc[0:5]
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
df.iloc[-5:]
# Out:
#             Rank                                          Major  \
# Major_code
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 3604        Biology & Life Science   9154   3878   5276    0.576360   33000
# 6109                        Health  48491  13487  35004    0.721866   33000
# 6100                        Health  33599   7574  26025    0.774577   32400
# 6102                        Health  38279   1225  37054    0.967998   28000
# 3609        Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.iloc[:5, :3] #bring the first 5 rows and fisrt 3 colums of those rows
# Out:
#             Rank                                      Major Major_category
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering

# %%
df["Major"]== "ECOLOGY"
# Out:
# Major_code
# 2419    False
# 2416    False
# 2415    False
# 2417    False
# 2418    False
#         ...
# 3604     True
# 6109    False
# 6100    False
# 6102    False
# 3609    False
# Name: Major, Length: 76, dtype: bool

# %%
df[df["Major"] == "ECOLOGY"]   #filters down the item
# Out:
#             Rank    Major          Major_category  Total   Men  Women  \
# Major_code
# 3604          72  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#             ShareWomen  Median
# Major_code
# 3604           0.57636   33000

# %%
df.loc[df["Major"] == "ECOLOGY"]
# Out:
#             Rank    Major          Major_category  Total   Men  Women  \
# Major_code
# 3604          72  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#             ShareWomen  Median
# Major_code
# 3604           0.57636   33000

# %%
df[df["ShareWomen"] > 0.5]
# Out:
#             Rank                                              Major  \
# Major_code
# 5001           7                         ASTRONOMY AND ASTROPHYSICS
# 6107          27                                            NURSING
# 5102          29  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 3702          35                    STATISTICS AND DECISION SCIENCE
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 5006          38                                       OCEANOGRAPHY
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 5003          51                                          CHEMISTRY
# ...

# %%
df[(df["ShareWomen"] > 0.5) & (df["Major_category"] == "Biology & Life Science")]

#two conditions & operator not AND or and
# Out:
#             Rank                                Major          Major_category  \
# Major_code
# 3607          36                         PHARMACOLOGY  Biology & Life Science
# 4006          43  COGNITIVE SCIENCE AND BIOPSYCHOLOGY  Biology & Life Science
# 3605          48                             GENETICS  Biology & Life Science
# 3603          49                    MOLECULAR BIOLOGY  Biology & Life Science
# 3606          52                         MICROBIOLOGY  Biology & Life Science
# 3601          54                 BIOCHEMICAL SCIENCES  Biology & Life Science
# 3602          55                               BOTANY  Biology & Life Science
# 1301          60                ENVIRONMENTAL SCIENCE  Biology & Life Science
# 3608          64                           PHYSIOLOGY  Biology & Life Science
# 3611          65                         NEUROSCIENCE  Biology & Life Science
# 3699          69                MISCELLANEOUS BIOLOGY  Biology & Life Science
# ...

# %%
df[(df["ShareWomen"] > 0.5) | (df["Major_category"] == "Biology & Life Science")]

#two conditions | operator NOT or OR
# Out:
#             Rank                                              Major  \
# Major_code
# 5001           7                         ASTRONOMY AND ASTROPHYSICS
# 6107          27                                            NURSING
# 5102          29  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 3702          35                    STATISTICS AND DECISION SCIENCE
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 5006          38                                       OCEANOGRAPHY
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 5003          51                                          CHEMISTRY
# ...

# %%
df[df["Major_category"].isin(["Health", "Biology & Life Science"])]

^#alternative way of doing filtering
# Out:
#             Rank                                              Major  \
# Major_code
# 6107          27                                            NURSING
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 3606          52                                       MICROBIOLOGY
# 3601          54                               BIOCHEMICAL SCIENCES
# 3602          55                                             BOTANY
# 6199          59           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 1301          60                              ENVIRONMENTAL SCIENCE
# ...
